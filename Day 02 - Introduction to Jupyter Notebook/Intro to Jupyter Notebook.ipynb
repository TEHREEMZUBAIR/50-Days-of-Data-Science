# %% [markdown]
# **TEHREEM ZUBAIR**
#
# **BYTEWISE FELLOWSHIP**
#
# **TASK 3**
#
# **GETTING FAMILIAR WITH JUPYTER NOTEBOOK**

# %% [markdown]
# ### **There are three types of cells in Notebook. We will explore them one by one:**

# %% [markdown]
# ## **1. CODE**
#
# This is where the code is typed and when executed the code will display the output below the cell.

# %%
#example python code
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %% [markdown]
# ## **2. MARKDOWN**
#
# Markdown is a popular markup language that is the superset of the HTML. Jupyter Notebook also supports markdown.

# %% [markdown]
# ### **ADDING HEADERS:**
#
# Heading can be added by prefixing any line by single or multiple ‘#’ followed by space.For example:
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4

# %% [markdown]
# ## **ADDING LIST:**
#
# Adding List is really simple in Jupyter Notebook. The unordered list can be added by using ‘*’ sign. Ordered list can be added by using numbering of each list item. For example:
# ### ORDERED LIST
# 1. Item 1
# 2. Item 2
#     1. Item 21
#     2. Item 22
#
# ### UNORDERED LIST
# * Item 1
# * Item 2
#     * Item 21
#     * Item 22

# %% [markdown]
# ## **ADDING LATEX EQUATION:**:
#
# $E = mc^2$
#
# $\mathrm{e}^{i \pi} - 1 = 0$.
#
# If we want equation to appear at the center of line then:
#
# \begin{align}
#         \mathbf{a} \cdot \mathbf{b} = \sum_{i=1}^n a_i b_i.
#     \end{align}

# %% [markdown]
# ## **ADDING TABLE:**
#
# | Column 1 | Column 2 | Column 3 |
# |:---------|:--------:|---------:|
# |  Row 1   |  Row 1   |  Row 1   |
# |  Row 2   |  Row 2   |  Row 2   |
# |  Row 3   |  Row 3   |  Row 3   |

# %% [markdown]
# ## **TEXT FORMATTING:**
# **BOLD**
#
# *ITALICIZE*
#
# > BLOCK QUOTE
#
# [LINK](https://www.geeksforgeeks.org/how-to-use-jupyter-notebook-an-ultimate-guide/)
#
# IMAGE
# ![IMAGE](https://media.geeksforgeeks.org/wp-content/uploads/20200120145051/jupyter-notebook-for-kernel.png)
