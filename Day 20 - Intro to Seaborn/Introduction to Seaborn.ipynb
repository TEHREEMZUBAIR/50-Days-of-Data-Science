# %% [markdown]
# ### **TEHREEM ZUBAIR**
# ### **BYTEWISE FELLOWSHIP**
# ### **TASK 18**
#
# ---
# ### **INTRODUCTION TO SEABORN**

# %% [markdown]
# ### **What is Seaborn?**
# Seaborn is a powerful Python library for creating data visualizations. It was developed in order to make it easy to create the most common types of plots.
#
# Data visualization is often a huge component of both the data exploration phase and the communication of results, so Seaborn will be very useful there.
#
# ### **Advantages of seaborn**
# There are several tools that can be used for data visualization, but Seaborn offers several advantages.
# 1. First, Seaborn's main purpose is to make data visualization easy. It was built to automatically handle a lot of complexity behind the scenes.
# 2. Second, Seaborn works extremely well with pandas data structures. pandas is a Python library that is widely used for data analysis.
# 3. Finally, it's built on top of Matplotlib, which is another Python visualization library. Matplotlib is extremely flexible. Seaborn allows you to take advantage of this flexibility when you need it, while avoiding the complexity that Matplotlib's flexibility can introduce.

# %% [markdown]
# Before moving to the data visualization with seaborn first import the liraries with conventional naming.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ### **INTRODUCTION TO DATA VISUALIZATION USING SEABORN**
# For illustrating scatter plots in seaborn I am using a countries data that has  information about 227 countries. This dataset has lots of interesting information on each country, such as the country's birth rates, death rates, and its gross domestic product (GDP). GDP is the value of all the goods and services produced in a year, expressed as dollars per person.

# %%
countries = pd.read_csv('/kaggle/input/data-of-countries/countries_data.csv')

# %%
countries.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %% [markdown]
# ### **Making a scatter plot with lists**
# In this part we will make lists from the provided dataframe and make a scatter plot with those lists.
#
# We've created three lists of data from this dataset to get you started.
# 1. **gdp** is a list that contains the value of GDP per country, expressed as dollars per person.
# 2. **phones** is a list of the number of mobile phones per 1,000 people in that country.
# 3. Finally, **percent_literate** is a list that contains the percent of each country's population that can read and write.

# %%
# GDP List
gdp = countries['GDP ($ per capita)']
gdp
# Out:
# 0        700.0
# 1       4500.0
# 2       6000.0
# 3       8000.0
# 4      19000.0
#         ...
# 222      800.0
# 223        NaN
# 224      800.0
# 225      800.0
# 226     1900.0
# Name: GDP ($ per capita), Length: 227, dtype: float64

# %%
# phones list
phones = countries['Phones (per 1000)']
phones
# Out:
# 0        3.2
# 1       71.2
# 2       78.1
# 3      259.5
# 4      497.2
#        ...
# 222    145.2
# 223      NaN
# 224     37.2
# 225      8.2
# 226     26.8
# Name: Phones (per 1000), Length: 227, dtype: float64

# %%
# percent_literate
percent_literate = countries['Literacy (%)']
percent_literate
# Out:
# 0       36.0
# 1       86.5
# 2       70.0
# 3       97.0
# 4      100.0
#        ...
# 222      NaN
# 223      NaN
# 224     50.2
# 225     80.6
# 226     90.7
# Name: Literacy (%), Length: 227, dtype: float64

# %%
# create the scatter plot
sns.scatterplot(x=gdp, y=phones)

# show the plot
plt.show()

# %% [markdown]
# Now we change the scatter plot so it displays the percent of the population that can read and write (percent_literate) on the y-axis.

# %%
sns.scatterplot(x=gdp, y=percent_literate)
plt.show()

# %% [markdown]
# While this plot does not show a linear relationship between GDP and percent literate, countries with a lower GDP do seem more likely to have a lower percent of the population that can read and write.

# %% [markdown]
# ### **Making countplot with a list**
# In the last exercise, we explored a dataset that contains information about 227 countries. Let's do more exploration of this data - specifically, how many countries are in each region of the world?
#
# To do this, we'll need to use a count plot. Count plots take in a categorical list and return bars that represent the number of list entries per category. You can create one here using a list of regions for each country, which is a variable named region.

# %%
region = countries['Region']
region
# Out:
# 0            ASIA (EX. NEAR EAST)
# 1      EASTERN EUROPE
# 2      NORTHERN AFRICA
# 3      OCEANIA
# 4      WESTERN EUROPE
#                       ...
# 222    NEAR EAST
# 223    NORTHERN AFRICA
# 224    NEAR EAST
# 225    SUB-SAHARAN AFRICA
# 226    SUB-SAHARAN AFRICA
# Name: Region, Length: 227, dtype: object

# %%
# Create count plot with region on the y-axis
sns.countplot(y=region)

# Show plot
plt.show()

# %% [markdown]
# ### **Making Count Plot with dataframe**
# In this exercise, we'll look at the responses to a survey sent out to young people.
# Our primary question here is: how many young people surveyed report being scared of spiders? Survey participants were asked to agree or disagree with the statement "I am afraid of spiders".
#
# Responses vary from 1 to 5, where 1 is "Strongly disagree" and 5 is "Strongly agree".

# %%
responses = pd.read_csv('/kaggle/input/responses/young-people-survey-responses.csv')
responses.head()
# Out:
#    Unnamed: 0  Music  Techno  Movies  History  Mathematics  Pets  Spiders  \
# 0           0    5.0     1.0     5.0      1.0          3.0   4.0      1.0
# 1           1    4.0     1.0     5.0      1.0          5.0   5.0      1.0
# 2           2    5.0     1.0     5.0      1.0          5.0   5.0      1.0
# 3           3    5.0     2.0     5.0      4.0          4.0   1.0      5.0
# 4           4    5.0     2.0     5.0      3.0          2.0   1.0      1.0
#
#    Loneliness  Parents' advice   Internet usage  Finances   Age  Siblings  \
# 0         3.0              4.0  few hours a day       3.0  20.0       1.0
# 1         2.0              2.0  few hours a day       3.0  19.0       2.0
# 2         5.0              3.0  few hours a day       2.0  20.0       2.0
# 3         5.0              2.0  most of the day       2.0  22.0       1.0
# 4         3.0              3.0  few hours a day       4.0  20.0       1.0
#
#    Gender Village - town
# 0  female        village
# ...

# %%
# Create count plot with spiders on x-axis
sns.countplot(x='Spiders', data=responses)
plt.show()

# %% [markdown]
# This plot shows us that most young people reported not being afraid of spiders.

# %% [markdown]
# ### **Adding a third variable hue**
# In this section, we'll see another big advantage that Seaborn offers: the ability to quickly add a third variable to your plots by adding color.
#
# - To showcase this cool feature in Seaborn, we'll be using tips dataset.
# - This dataset contains one row for each table served at a restaurant and has information about things like the bill amount, how many people were at the table, and when the table was served.
# - Let's explore the relationship between the "total_bill" and "tip" columns using a scatter plot.

# %%
tips = pd.read_csv("/kaggle/input/tipsdataset/tips.csv")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.show()

# %% [markdown]
# We can set the "hue" parameter equal to the DataFrame column name "smoker" and then Seaborn will automatically color each point by whether they are a smoker.Plus it will also add alegend automatically.

# %%
sns.scatterplot(x='total_bill', y='tip', hue='smoker', data=tips)
plt.show()

# %% [markdown]
# ##### **Setting hue order**
#
# Hue also allows us to assert more control over the ordering and coloring of each value. The "hue order" parameter takes in a list of values and will set the order of the values in the plot accordingly. Notice how the legend for smoker now lists "yes" before "no".

# %%
sns.scatterplot(x='total_bill', y='tip', hue='smoker', hue_order=['Yes', 'No'], data=tips)
plt.show()

# %% [markdown]
# ##### **Specifying hue colors**
# - We can also control the colors assigned to each value using the "palette" parameter.
# - This parameter takes in a dictionary, which is a data structure that has key-value pairs. This dictionary should map the variable values to the colors you want to represent the value.
# - Here, we create a dictionary called "hue colors" that maps the value "Yes" to the color black and the value "No" to the color red.
# - When we set hue equal to "smoker" and the palette parameter equal to this dictionary, we have a scatter plot where smokers are represented with black dots and non-smokers are represented with red dots.

# %%
hue_colors = {"Yes" : "Black",
              "No" : "Red"
}

# %%
sns.scatterplot(x='total_bill', y='tip', hue='smoker', hue_order=['Yes', 'No'], palette = hue_colors, data=tips)
plt.show()

# %% [markdown]
# ##### **Using HTML hex codes with hue**
# Here's an example using HTML hex codes. Make sure you put the hex codes in quotes with a pound sign at the beginning.

# %%
hue_colors = {"Yes" : "#808080",
              "No" : "#00FF00"
}

# %%
sns.scatterplot(x='total_bill', y='tip', hue='smoker', hue_order=['Yes', 'No'], palette = hue_colors, data=tips)
plt.show()

# %% [markdown]
# ##### **Using hue with count plots**
# hue is available in most of Seaborn's plot types.
# For example, this count plot shows the number of observations we have for smokers versus non-smokers, and setting "hue" equal to "sex" divides these bars into subgroups of males versus females.
# From this plot, we can see that males outnumber females among both smokers and non-smokers in this dataset.

# %%
hue_colors = {"Male" : "skyblue",
             "Female" : "Pink"}

# %%
sns.countplot(x='smoker', data=tips, hue='sex', palette=hue_colors )
plt.show()

# %% [markdown]
# ---
# ## **VISUALIZING TWO QUANTITATIVE VARIABLES**
# In this section we will create and customize plots that visualize the relationship between two quantitative variables.
# To do this, you will use scatter plots and line plots to explore how the level of air pollution in a city changes over the course of a day and how horsepower relates to fuel efficiency in cars. You will also see another big advantage of using Seaborn - the ability to easily create subplots in a single figure!
#
#
#
# ### **Introduction to relational plots and subplots**
#
# Many questions in data science are centered around describing the relationship between two quantitative variables. Seaborn calls plots that visualize this relationship "relational plots".
#
# While looking at a relationship between two variables at a high level is often informative, sometimes we suspect that the relationship may be different within certain subgroups.
# In the last section, we started to look at subgroups by using the "hue" parameter to visualize each subgroup using a different color on the same plot.
#
# - In this section, we'll try out a different method: **creating a separate plot per subgroup.**
# - To do this, we're going to introduce a new Seaborn function: "relplot()". "relplot()" stands for "relational plot" and enables you to visualize the relationship between two quantitative variables using either scatter plots or line plots.
# - Using "relplot()" gives us a big advantage: the ability to create subplots in a single figure.
# - Because of this advantage, we'll be using "relplot()" instead of "scatterplot()".
#
#
# Let's return to our scatter plot of total bill versus tip amount from the tips dataset. We see how to create a scatter plot with the "scatterplot" function.
#
# To make it with "relplot()" instead, we change the function name to "relplot()" and use the "kind" parameter to specify what kind of relational plot to use - scatter plot or line plot. In this case, we'll set kind equal to the word "scatter".
#
# By setting "col" equal to "smoker", we get a separate scatter plot for smokers and non-smokers, arranged horizontally in columns.

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', col='smoker')

# %% [markdown]
# ##### **Subplots in rows**
# If we want to arrange these vertically in rows instead, we can use the "row" parameter instead of "col".

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', row='smoker')

# %% [markdown]
# ##### **Subplots in rows and columns**
# It is possible to use both "col" and "row" at the same time. Here, we set "col" equal to smoking status and "row" equal to the time of day (lunch or dinner). Now we have a subplot for each combination of these two categorical variables.

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', col='smoker', row='time')

# %% [markdown]
# ##### **Wrapping columns**
# As another example, let's look at subgroups based on day of the week. There are four subplots here, which can be a lot to show in a single row.
#
# To address this, you can use the "col_wrap" parameter to specify how many subplots you want per row.
#
# Here, we set "col_wrap" equal to two plots per row.

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', col='day', col_wrap=2)

# %% [markdown]
# ##### **Ordering columns**
# We can also change the order of the subplots by using the "col_order" and "row_order" parameters and giving it a list of ordered values.

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter',
            col='day', col_wrap=2, col_order=['Thur', 'Fri', 'Sat', 'Sun'])
plt.show()

# %% [markdown]
# ### **Customizing Scatter plots**
# So far, we've only scratched the surface of what we're able to do with scatter plots in Seaborn.
#
# As a reminder, scatter plots are a great tool for visualizing the relationship between two quantitative variables.
# - We've seen a few ways to add more information to them as well, by creating subplots or plotting subgroups with different colored points.
# - In addition to these, Seaborn allows you to add more information to scatter plots by varying the size, the style, and the transparency of the points.
# - All of these options can be used in both the "scatterplot()" and "relplot()" functions, but we'll continue to use "relplot()" since it's more flexible and allows us to create subplots.
# - We'll use the tips dataset to learn how to use each customization and cover best practices for deciding which customizations to use.

# %% [markdown]
# #### **Subgroups with point size**
# The first customization we'll talk about is point size.
# - Here, we're creating a scatter plot of total bill versus tip amount. - We want each point on the scatter plot to be sized based on the number of people in the group, with larger groups having bigger points on the plot.
# - To do this, we'll set the "size" parameter equal to the variable name "size" from our dataset.
#
# As this example demonstrates, varying point size is best used if the variable is either a quantitative variable or a categorical variable that represents different levels of something, like "small", "medium", and "large". This plot is a bit hard to read because all of the points are of the same color.

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', size='size')
plt.show()

# %% [markdown]
# #### **Point size and hue**
# We can make the above plt easier to understand by using the "size" parameter in combination with the "hue" parameter.
# - To do this, set "hue" equal to the variable name "size".
# - Notice that because "size" is a quantitative variable, Seaborn will automatically color the points different shades of the same color instead of different colors per category value like we saw in previous plots.
# - Now larger groups have both larger and darker points, which provides better contrast and makes the plot easier to read.

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter',
            size='size', hue='size')
plt.show()

# %% [markdown]
# #### **Subgroups with point size**
# Now we'll look at is the point style.
# - Setting the "style" parameter to a variable name will use different point styles for each value of the variable.
# - Here's a scatter plot we've seen before, where we use "hue" to create different colored points based on smoking status.
# - Setting "style" equal to "smoker" allows us to better distinguish these subgroups by plotting smokers with a different point style in addition to a different color.

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter',
            hue='smoker', style='smoker')
plt.show()

# %% [markdown]
# #### **Changing points transparency**
# The last customization we'll look at is point transparency.
# - Setting the "alpha" parameter to a value between 0 and 1 will vary the transparency of the points in the plot, with 0 being completely transparent and 1 being completely non-transparent.
# - Here, we've set "alpha" equal to 0.4.
# - This customization can be useful when you have many overlapping points on the scatter plot, so you can see which areas of the plot have more or less observations.

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', alpha=0.4)
plt.show()

# %% [markdown]
# ### **Introduction to Line plots**
# In Seaborn, we have two types of relational plots: scatter plots and line plots.
#
# While each point in a scatter plot is assumed to be an independent observation, line plots are the visualization of choice when we need to track the same thing over time. A common example is tracking the value of a company's stock over time.
#
# In this exercise, we'll continue to explore Seaborn's mpg dataset, which contains one row per car model and includes information such as the year the car was made, its **fuel efficiency (measured in "miles per gallon" or "M.P.G")**, and its **country of origin (USA, Europe, or Japan)**.

# %%
cars_data = pd.read_csv('/kaggle/input/carsdata/mpg.csv')
cars_data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# By specifying "kind" equals "line", using relplot() and the mpg DataFrame to create a line plot with "model_year" on the x-axis and "mpg" on the y-axis.

# %%
# Create line plot
sns.relplot(x='model_year', y='mpg', data=cars_data, kind='line')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# The shaded region represents a confidence interval for the mean, not the distribution of the observations.
#
# From the above plot we can see that:
# - The average miles per gallon has generally increased over time.
# - The 95% confidence interval for average miles per gallon in 1970 is approximately 16 - 19.5 miles per gallon.

# %% [markdown]
# #### **Visualizing standard deviation with line plots**
# In the last exercise, we looked at how the average miles per gallon achieved by cars has changed over time. Now let's use a line plot to visualize how the distribution of miles per gallon has changed over time.

# %%
# Create line plot
sns.relplot(x='model_year', y='mpg', data=cars_data, kind='line', ci='sd')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Unlike the plot in the last exercise, this plot shows us the distribution of miles per gallon for all the cars in each year.

# %% [markdown]
# #### **Plotting subplots in line plots**
# We've seen that the average miles per gallon for cars has increased over time, but how has the average horsepower for cars changed over time? And does this trend differ by country of origin?

# %%
# Create line plot of model year vs. horsepower
sns.relplot(x="model_year", y="horsepower", data=cars_data, kind="line", ci=None)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Create different lines for each country of origin ("origin") that vary in both line style and color.**
#
# Setting the "style" and "hue" parameters equal to the variable name "location" creates different lines for each origin that vary in both line style and color.

# %%
# Create line plot of model year vs. horsepower
sns.relplot(x="model_year", y="horsepower", data=cars_data, kind="line", errorbar=None,
           style='origin', hue='origin')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### **Adding Markers**
# Setting the "markers" parameter equal to "True" will display a marker for each data point. The marker will vary based on the subgroup you've set using the "style" parameter.
#
# If you don't want the line styles to vary by subgroup, set the "dashes" parameter equal to "False".

# %%
# Create line plot of model year vs. horsepower
sns.relplot(x="model_year", y="horsepower", data=cars_data, kind="line", errorbar=None,
           style='origin', hue='origin', markers=True, dashes=False)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ---
# ## **VISUALIZING A CATEGORICAL AND A QUANTITATIVE VARIABLE**
# Categorical variables are present in nearly every dataset, but they are especially prominent in survey data.
#
# In this section, we will learn how to create and customize categorical plots such as box plots, bar plots, count plots, and point plots.
#
# Along the way, you will explore survey data from young people about their interests, students about their study habits, and adult men about their feelings about masculinity.

# %% [markdown]
# ### **Count plots and Bar plots**
# - Count plots and bar plots are two types of visualizations that Seaborn calls "categorical plots".
# - Categorical plots involve a categorical variable, which is a variable that consists of a fixed, typically small number of possible values, or categories.
# - These types of plots are commonly used when we want to make comparisons between different groups. - As a reminder, a count plot displays the number of observations in each category.

# %% [markdown]
# #### **catplot()**
# - Just like we used "relplot()" to create different types of relational plots, in this section we'll be using "catplot()" to create different types of categorical plots.
# - "catplot()" offers the same flexibility that "relplot()" does, which means it will be easy to create subplots if we need to using the same "col" and "row" parameters.

# %% [markdown]
# In this exercise, we'll return to exploring our dataset that contains the responses to a survey sent out to young people. We might suspect that young people spend a lot of time on the internet, but how much do they report using the internet each day? Let's use a count plot to break down the number of survey responses in each category and then explore whether it changes based on age.

# %%
responses.head()
# Out:
#    Unnamed: 0  Music  Techno  Movies  History  Mathematics  Pets  Spiders  \
# 0           0    5.0     1.0     5.0      1.0          3.0   4.0      1.0
# 1           1    4.0     1.0     5.0      1.0          5.0   5.0      1.0
# 2           2    5.0     1.0     5.0      1.0          5.0   5.0      1.0
# 3           3    5.0     2.0     5.0      4.0          4.0   1.0      5.0
# 4           4    5.0     2.0     5.0      3.0          2.0   1.0      1.0
#
#    Loneliness  Parents' advice   Internet usage  Finances   Age  Siblings  \
# 0         3.0              4.0  few hours a day       3.0  20.0       1.0
# 1         2.0              2.0  few hours a day       3.0  19.0       2.0
# 2         5.0              3.0  few hours a day       2.0  20.0       2.0
# 3         5.0              2.0  most of the day       2.0  22.0       1.0
# 4         3.0              3.0  few hours a day       4.0  20.0       1.0
#
#    Gender Village - town
# 0  female        village
# ...

# %%
# Create a count plot
sns.catplot(x='Internet usage', data=responses, kind='count')
plt.xticks(rotation=90)
plt.show()

# %%
# Create a count plot
sns.catplot(y='Internet usage', data=responses, kind='count')
plt.show()

# %% [markdown]
# #### **Changing the order**
# Sometimes there is a specific ordering of categories that makes sense for these plots.
# - In this case, it makes more sense for the categories to be in order from no time at all to most of the day.
# - To change the order of the categories, create a list of category values in the order that you want them to appear, and then use the "order" parameter.
# - This works for all types of categorical plots, not just count plots.

# %%
category_order = ['no time at all',
                 'less than an hour a day',
                 'few hours a day',
                 'most of the day']

# %%
# Create a count plot
sns.catplot(x='Internet usage', data=responses, kind='count', order=category_order)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Separate this plot into two side-by-side column subplots based on "Gender", which separates respondents into those that male and female.

# %%
# Separate into column subplots based on age category
sns.catplot(y="Internet usage", data=responses, col="Gender",
            kind="count", order=category_order)

# Show plot
plt.show()

# %% [markdown]
# #### **Bar plots**
# Bar plots look similar to count plots, but instead of the count of observations in each category, they show the mean of a quantitative variable among observations in each category.
#
# - This bar plot uses the tips dataset and shows the average bill paid among people who visited the restaurant on each day of the week.
# - From this, we can see that the average bill is slightly higher on the weekends. To create this bar plot, we use "catplot".
# - Specify the categorical variable "day" on the x-axis, the quantitative variable "total bill" on the y-axis, and set the "kind" parameter equal to "bar".

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='bar')
plt.show()

# %% [markdown]
# Notice also that Seaborn automatically shows 95% confidence intervals for these means. Just like with line plots, these confidence intervals show us the level of uncertainty we have about these estimates. Assuming our data is a random sample of some population, we can be 95% sure that the true population mean in each group lies within the confidence interval shown.

# %% [markdown]
# #### **Turning off confidence interval**
# If we want to turn off these confidence intervals, we can do this by setting the "ci" parameter equal to "None" - just like we did with line plots.

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='bar', ci=None)
plt.show()
# Out:
# /tmp/ipykernel_33/3408236275.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(x='day', y='total_bill', data=tips, kind='bar', ci=None)

# %% [markdown]
# #### **Changing the orientation**
# We can also change the orientation of the bars in bar plots and count plots by switching the x and y parameters. However, it is fairly common practice to put the categorical variable on the x-axis.

# %%
sns.catplot(y='day', x='total_bill', data=tips, kind='bar', ci=None)
plt.show()
# Out:
# /tmp/ipykernel_33/770296369.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(y='day', x='total_bill', data=tips, kind='bar', ci=None)

# %% [markdown]
# #### **Box plots**
# A box plot shows the distribution of quantitative data.
# - The colored box represents the 25th to 75th percentile, and the line in the middle of the box represents the median.
# - The whiskers give a sense of the spread of the distribution, and the floating points represent outliers.
# - Box plots are commonly used as a way to compare the distribution of a quantitative variable across different groups of a categorical variable.
#
# Now let's look at how to create a box plot in Seaborn.
# - While Seaborn does have a "boxplot()" function, we'll be using the "catplot()" function that we introduced in an earlier lesson because it makes it easy to create subplots using the "col" and "row" parameters.
# - We'll put the categorical variable "time" on the x-axis and the quantitative variable "total bill" on the y-axis.
# - Here, we want box plots, so we'll specify kind="box". That's it! We have a nice looking box plot. Next, we'll look at different ways to customize this plot.

# %%
g = sns.catplot(x='time', y='total_bill', data=tips, kind='box')
plt.show()

# %% [markdown]
# #### **Changing the order of categories**
# As a reminder, "catplot" allows you to change the order of the categories using the "order" parameter. Here, we specified that "dinner" should be shown before "lunch".

# %%
g = sns.catplot(x='time', y='total_bill', data=tips, kind='box', order=['Lunch', 'Dinner'])
plt.show()

# %% [markdown]
# #### **Omitting outliers using sym**
# - Occasionally, we may want to omit the outliers from your box plot. You can do this using the "sym" parameter.
# - If you pass an empty string into "sym", it will omit the outliers from your plot altogether.
# - "Sym" can also be used to change the appearance of the outliers instead of omitting them.

# %%
g = sns.catplot(x='time', y='total_bill', data=tips, kind='box',
                order=['Lunch', 'Dinner'], sym='')
plt.show()

# %% [markdown]
# #### **Changing the whiskers using 'whis'**
# By default, the whiskers extend to 1.5 times the interquartile range, or "IQR".
# - The IQR is the 25th to the 75th percentile of a distribution of data.
# - If you want to change the way the whiskers in your box plot are defined, you can do this using the "whis" parameter.
# - There are several options for changing the whiskers.
#   - You can change the range of the whiskers from 1.5 times the IQR (which is the default) to 2 times the IQR by setting "whis" equal to 2.0.
#   - Alternatively, you can have the whiskers define specific lower and upper percentiles by passing in a list of the lower and upper values
#   - Finally, you may just want to draw the whiskers at the min and max values. You can do this by specifying the lower percentile as 0 and the upper percentile as 100.

# %%
sns.catplot(x='time', y='total_bill', data=tips, kind='box',
                order=['Lunch', 'Dinner'], whis=2.0)
plt.show()

# %%
sns.catplot(x='time', y='total_bill', data=tips, kind='box',
                order=['Lunch', 'Dinner'], whis=[5, 95])
plt.show()

# %%
sns.catplot(x='time', y='total_bill', data=tips, kind='box',
                order=['Lunch', 'Dinner'], whis=[0, 100])
plt.show()

# %% [markdown]
# ---
# ## **CUSTOMIZING SEABORN PLOTS**
# In this section, you will learn how to add informative plot titles and axis labels, which are one of the most important parts of any data visualization! We will also learn how to customize the style of your visualizations in order to more quickly orient your audience to the key takeaways. Then, you will put everything you have learned together for the final exercises of the study!
#
# ### **Why customize?**
# By default, Seaborn plots are pleasing to look at, but there are several reasons you may want to change the appearance.
#
# Changing the style of a plot can be motivated by personal preference, but it can also help improve its readability or help orient an audience more quickly to the key takeaway.

# %% [markdown]
# ### **Changing Figure style**
# Seaborn has five preset figure styles which change the background and axes of the plot.
# - You can refer to them by name:
# > 1. white
# > 2. dark
# > 3. whitegrid
# > 4. darkgrid
# > 5. ticks
# - To set one of these as the global style for all of your plots, use the "set style" function.
#
# **Default figure style(white)**
# - The default style is called "white" and provides clean axes with a solid white background.
# - If we only care about the comparisons between groups or the general trend across age groups instead of the specific values, this is a good choice.

# %%
# Create line plot of model year vs. horsepower with default figure style
sns.relplot(x="model_year", y="horsepower", data=cars_data, kind="line", errorbar=None,
           style='origin', hue='origin', markers=True, dashes=False)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Applying figure styles**
# - Changing the style to "whitegrid" will add a gray grid in the background.
# - This is useful if you want your audience to be able to determine the specific values of the plotted points instead of making higher level observations.

# %%
sns.set_style('whitegrid')
# Create line plot of model year vs. horsepower with whitegrid figure style
sns.relplot(x="model_year", y="horsepower", data=cars_data, kind="line", errorbar=None,
           style='origin', hue='origin', markers=True, dashes=False)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# The other styles are variants on these.
# - "ticks" is similar to "white", but adds small tick marks to the x- and y-axes.
# - "dark" provides a gray background
# - "darkgrid" provides a gray background with a white grid.

# %% [markdown]
# ### **Changing the palette**
# - We can change the color of the main elements of the plot with Seaborn's "set palette" function. - - Seaborn has many preset color palettes that we can refer to by name, or we can create your own custom palette. Let's see an example.

# %% [markdown]
# **Diverging palettes**
# Seaborn has a group of preset palettes called diverging palettes that are great to use if your visualization deals with a scale where the two ends of the scale are opposites and there is a neutral midpoint.
#
# Here are some examples of diverging palettes - red/blue and purple/green.
# 1. RdBu
# 2. PRGn
#
# Note that if you append the palette name with "_r", you can reverse the palette.

# %% [markdown]
# **Default palette**

# %%
# Create a count plot
sns.catplot(x='Internet usage', data=responses, kind='count', order=category_order)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Applying divergence palette**
# Setting this plot's palette to red/blue diverging provides a clearer contrast between people who dosnot use internet at all and people who use internet most of the day.

# %%
sns.set_palette('RdBu')
# Create a count plot
sns.catplot(x='Internet usage', data=responses, kind='count', order=category_order)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Sequential Palettes**
#
# Another group of palettes are called sequential palettes. These are a single color (or two colors blended) moving from light to dark values.
#
# Sequential palettes are great for emphasizing a variable on a continuous scale. One example is this plot depicting the relationship between a car's horsepower and its miles per gallon, where points grow larger and darker when the car has more cylinders.

# %%
cars_data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.set_style('white')
sns.relplot(x='horsepower', y='mpg', data=cars_data, kind='scatter',
            size='cylinders', hue='cylinders')
plt.show()

# %% [markdown]
# #### **Custom palettes**
# You can also create your own custom palettes by passing in a list of color names or a list of hex color codes.

# %%
custom_palette = ['#FBB4AE', '#B3CDE3', '#CCEBC5',
                  '#DECBE4', '#FED9A6', '#FFFFCC',
                  '#E5D88D', '#FDDAEC', '#F2F2F2',
                  '#FFA07A', '#CCCCFF']
sns.set_palette(custom_palette)

# %%
# Create count plot with region on the y-axis
sns.catplot(y='Region', data=countries, kind='count')

# Show plot
plt.show()

# %% [markdown]
# ### **Changing the scale**
# Finally, we can change the scale of your plot by using the "set context" function. The scale options from smallest to largest are "paper", "notebook", "talk", and "poster".
#
# The default context is "paper".
#
# We'll want to choose a larger scale like "talk" for posters or presentations where the audience is further away from the plot.

# %%
sns.set_context('talk')
sns.relplot(x='horsepower', y='mpg', data=cars_data, kind='scatter',
            size='cylinders', hue='cylinders')
plt.show()

# %%
sns.set_context('notebook')
sns.set_style('whitegrid')
# Create line plot of model year vs. horsepower with whitegrid figure style
sns.relplot(x="model_year", y="horsepower", data=cars_data, kind="line", errorbar=None,
           style='origin', hue='origin', markers=True, dashes=False)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### **Adding titles and labels**
#
# In this section, we'll go over one of the most important parts of any data visualization: plot titles and axis labels.
#
# We create data visualizations to communicate information, and we can't do that effectively without a clear title and informative axis labels. To see this, we make a simple visualization. Below, we see box plots showing the distribution of birth rates for countries in each of 11 regions.

# %%
sns.set_palette('RdBu')
sns.catplot(x='Region', y='Birthrate', data=countries, kind='box')
plt.show()

# %% [markdown]
# From the above plot we cannot clearly retreive any information by just looking at it. It needs certain modifications.
# 1. A title needs to be added, which will immediately orient the audience to what they're looking at.
# 2. Make he axis labels are more informative, making it clearer that birth rate is measured per one thousand people and birth rates are measured per country in each region.
# 3. Finally, the x-axis tick labels should be rotated to make it clear what each region is called.
#
# Let's learn how to make these changes.

# %% [markdown]
# #### **FacetGrid vs. AxesSubplot objects**
# Before we go into the details of adding a title, we need to understand an underlying mechanism in Seaborn.
#
# Seaborn's plot functions create two different types of objects: FacetGrids and AxesSubplots.
#
# To figure out which type of object you're working with, first assign the plot output to a variable.
#
# The variable is often named "g", so we'll do that here as well. Write "type" "g" to return the object type.
#
# This scatter plot is an AxesSubplot.

# %%
g = sns.scatterplot(x='Region', y='Birthrate', data=countries)
type(g)
# Out:
# matplotlib.axes._axes.Axes

# %%
g = sns.catplot(x='Region', y='Birthrate', data=countries, kind='box')
type(g)
# Out:
# seaborn.axisgrid.FacetGrid

# %% [markdown]
# | Object Type | Plot Type                   | Characteristics                        |
# |-------------|-----------------------------|----------------------------------------|
# | FacetGrid   | `relplot()`, `catplot()`    | Can create subplots                    |
# | AxesSubplot | `scatterplot()`, `countplot()` etc. | Only create a single plot              |
#
#
# A FacetGrid consists of one or more AxesSubplots, which is how it supports subplots.
#
# Recall that "relplot()" and "catplot()" both support making subplots. This means that they are creating FacetGrid objects. In contrast, single-type plot functions like "scatterplot()" and "countplot()" return a single AxesSubplot object.

# %% [markdown]
# Adding  a title to FacetGrid
# Let's return to our messy plot from the beginning.
#
# Recall that "catplot()" enables subplots, so it returns a FacetGrid object.
#
# To add a title to a FacetGrid object, first assign the plot to the variable "g".
#
# After you assign the plot to "g", you can set the title using "g dot fig dot suptitle".
#
# This tells Seaborn you want to set a title for the figure as a whole.

# %%
g = sns.catplot(x='Region', y='Birthrate', data=countries, kind='box')
g.fig.suptitle('New Title')
plt.show()

# %% [markdown]
# #### **Adjusting height of title in FacetGrid**
#
# Note that by default, the figure title might be a little low.
#
# To adjust the height of the title, you can use the "y" parameter.
#
# The default value is 1, so setting it to 1.3 will make it a little higher than the default.

# %%
g = sns.catplot(x='Region', y='Birthrate', data=countries, kind='box')
g.fig.suptitle('New Title', y=1.03)
plt.show()

# %% [markdown]
# #### **Adding title to AxesSubplot**
# To add a title to an AxesSubplot object like that from the "box plot" function, assign the plot to a variable and use “g dot set_title”. We can also use the “y” parameter here to adjust the height of the title.

# %%
g = sns.boxplot(x='Region', y='Birthrate', data=countries)
g.set_title('New Title', y=1.03)
# Out:
# Text(0.5, 1.03, 'New Title')

# %% [markdown]
# #### **Title for subplots**
# Now let's look at what happens if the figure has subplots. Let's say we've divided countries into two groups - group one and group two - and we've set "col" equal to "Group" to create a subplot for each group.

# %%
countries.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
# Adding the 'Group' column
mid_index = len(countries) // 2
countries['Group'] = ['Group 1'] * mid_index + ['Group 2'] * (len(countries) - mid_index)

# Verifying the result
countries[ 'Group'].value_counts()
# Out:
# Group
# Group 2    114
# Group 1    113
# Name: count, dtype: int64

# %%
g = sns.catplot(x='Region', y='Birthrate', data=countries, kind='box', col='Group')
g.fig.suptitle('New Title', y=1.03)
# Out:
# Text(0.5, 1.03, 'New Title')

# %% [markdown]
# To alter the subplot titles, use "g.set_titles" to set the titles for each AxesSubplot.
#
# If you want to use the variable name in the title, you can use "col name" in braces to reference the column value.
#
# Here, we've created subplot titles that display as "this is group 2" and "this is group 1".

# %%
g = sns.catplot(x='Region', y='Birthrate', data=countries, kind='box', col='Group')
g.fig.suptitle('New Title', y=1.03)
g.set_titles('This is {col_name}')

# %% [markdown]
# ### **Adding Axis Labels**
# To add axis labels, assign the plot to a variable and then call the "set" function.
#
# Set the parameters "x label" and "y label" to set the desired x-axis and y-axis labels, respectively.
#
# This works with both FacetGrid and AxesSubplot objects.

# %%
g = sns.catplot(x='Region', y='Birthrate', data=countries, kind='box')
g.fig.suptitle('New Title', y=1.03)
g.set(xlabel='New X Label',
      ylabel='New Y Label')
plt.show()

# %% [markdown]
# #### **Rotating x-axis tick labels**
# Sometimes, like in the example we've seen in this lesson, your tick labels may overlap, making it hard to interpret the plot.
#
# One way to address this is by rotating the tick labels. To do this, we don't call a function on the plot object itself.
#
# Instead, after we create the plot, we call the matplotlib function "plt.xticks" and set "rotation" equal to 90 degrees.
#
# This works with both FacetGrid and AxesSubplot objects.

# %%
g = sns.catplot(x='Region', y='Birthrate', data=countries, kind='box')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### **Putting it altogether**
#
# we've learned a great deal about how to create effective data visualizations in Seaborn. Now review what we've learned and connect the pieces together to form a cohesive picture of how to use Seaborn for future projects.
#
# **Getting Started**
#
# To import Seaborn:
# `import seaborn as sns`
#
# To import Matplotlib:
# `import matplotlib.pyplot as plt`
#
# To show a plot:
# `plt.show()`
#
#
# **Relational Plots**
# - Show the relationship between two quantitative variables.
# - Examples: scatter plots and line plots.
#
# `sns.relplot(x="x_variable_name", y="y_variable_name", data=pandas_df, kind="scatter/line")`
#
#
# **Categorical Plots**
#
# - These describe the distribution of a quantitative variable within categories given by a categorical variable.
# - Examples: bar, count, box and point plots
#
# `sns.catplot(x="x_variable_name", y="y_variable_name", data=pandas_df, kind="bar")`
#
# **Adding a third variable (hue)**
#
# Setting `hue` will create subgroups that are displayed as different clors on a single plot.
#
# **Adding a third variable (row/col)**
#
# Setting `row` and/or `col` in `relplot()` or `catplot()` will create subgroups that are dispalyed on separate subplots.
#
# **Customization**
# - Change the background: `sns.set_style()`
# - Change the main element colors: `sns.set_palette()`
# - Change the scale: `sns.set_context()`
#
# **Adding a title**
#
# | Object Type | Plot Type                   | How to add Title                        |
# |-------------|-----------------------------|----------------------------------------|
# | FacetGrid   | `relplot()`, `catplot()`    | `g.fig.suptitle()`                    |
# | AxesSubplot | `scatterplot()`, `countplot()` etc. | `g.set_title()`
# |
#
# **Adding Labels**
# Add x- and y-axis labels
#
# `.set(xlabel='New X Label', ylabel='New Y Label')`
#
# Rotate xticks
# `plt.xticks(rotaion=90)`
